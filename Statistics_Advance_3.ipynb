# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import t
from scipy.stats import ttest_ind

# %% [markdown]
# A1: Estimation Statistics
# Estimation statistics involves estimating population parameters based on sample data. A point estimate is a single value used to approximate the population parameter, while an interval estimate provides a range within which the parameter is likely to fall.

# %%
def estimate_population_mean(sample_mean, sample_std, sample_size):
    margin_of_error = 1.96 * (sample_std / (sample_size ** 0.5))
    confidence_interval = (sample_mean - margin_of_error, sample_mean + margin_of_error)
    return confidence_interval

# %% [markdown]
# Q3: Hypothesis Testing
# Hypothesis testing is a statistical method to make inferences about population parameters based on sample data. It is used to assess claims and make decisions about the population using evidence from the sample.
#
# Q4: Hypothesis on Average Weight
# Hypothesis: The average weight of male college students is greater than the average weight of female college students.

# %% [markdown]
# Q6: Null and Alternative Hypotheses
# Null hypothesis (H0) represents no effect or no difference, while alternative hypothesis (H1) posits a specific effect or difference. Example: H0: μ = 50, H1: μ ≠ 50.

# %% [markdown]
# Q7: Steps in Hypothesis Testing
#
# * State Hypotheses
# * Choose Significance Level (α)
# * Collect Data and Perform Test
# * Analyze Results
# * Make Decision and Draw Conclusion
#
# Q8: P-value in Hypothesis Testing
# The p-value is the probability of obtaining results as extreme as the observed ones, assuming the null hypothesis is true. A smaller p-value suggests stronger evidence against the null hypothesis.

# %%
#Q9: Student's t-Distribution Plot in Python
degrees_of_freedom = 10
x = np.linspace(-3, 3, 1000)
plt.plot(x, t.pdf(x, df=degrees_of_freedom))
plt.title(f"Student's t-Distribution (df={degrees_of_freedom})")
plt.show()

# %%
#Q10: Python Program for Two-Sample t-Test
def two_sample_t_test(sample1, sample2):
    t_stat, p_value = ttest_ind(sample1, sample2)
    return t_stat, p_value

# %% [markdown]
# Q11: Student's t distribution is a probability distribution used in statistical inference for small sample sizes. It's similar to the normal distribution but has heavier tails. It's used when the population standard deviation is unknown and sample sizes are small.
#
# Q12: The t-statistic is a measure that quantifies the difference between the sample mean and the population mean in terms of the sample standard deviation. The formula for t-statistic is (x̄ - μ) / (s / √n), where x̄ is the sample mean, μ is the population mean, s is the sample standard deviation, and n is the sample size.
#
# Q13: The 95% confidence interval for the population mean revenue is $500 ± $1.96 * ($50 / √50), resulting in an interval of $484.92 to $515.08.
#
# Q14: The null hypothesis is rejected if the t-statistic (calculated as (x̄ - μ) / (s / √n)) is less than -1.96 or greater than 1.96 at a 0.05 significance level. In this case, the calculated t-statistic is (8 - 10) / (3 / √100) = -6.67, leading to the rejection of the null hypothesis.
#
# Q15: The null hypothesis is rejected if the t-statistic (calculated as (x̄ - μ) / (s / √n)) is less than -2.48 at a 0.01 significance level. In this case, the calculated t-statistic is (4.8 - 5) / (0.5 / √25) = -2, leading to the rejection of the null hypothesis.
#
# Q16: The null hypothesis is tested using a two-sample t-test. The calculated t-statistic is (80 - 75) / √[(10^2/30) + (8^2/40)] = 2.65. Since 2.65 is not greater than the critical value for a 0.01 significance level, the null hypothesis is not rejected.
#
# Q17: The 99% confidence interval for the population mean number of ads watched is 4 ± 2.68 * (1.5 / √50), resulting in an interval of 3.33 to 4.67.
