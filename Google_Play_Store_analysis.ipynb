# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\Admin\eclipse\Downloads\apps.csv\apps.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                                                App  \
# 0           0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1           1                                Coloring book moana
# 2           2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3           3                              Sketch - Draw & Paint
# 4           4              Pixel Draw - Number Art Coloring Book
#
#          Category  Rating  Reviews  Size     Installs  Type Price  \
# 0  ART_AND_DESIGN     4.1      159  19.0      10,000+  Free     0
# 1  ART_AND_DESIGN     3.9      967  14.0     500,000+  Free     0
# 2  ART_AND_DESIGN     4.7    87510   8.7   5,000,000+  Free     0
# 3  ART_AND_DESIGN     4.5   215644  25.0  50,000,000+  Free     0
# 4  ART_AND_DESIGN     4.3      967   2.8     100,000+  Free     0
#
#   Content Rating                     Genres      Last Updated  \
# 0       Everyone               Art & Design   January 7, 2018
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9659 entries, 0 to 9658
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      9659 non-null   int64
#  1   App             9659 non-null   object
#  2   Category        9659 non-null   object
#  3   Rating          8196 non-null   float64
#  4   Reviews         9659 non-null   int64
#  5   Size            8432 non-null   float64
#  6   Installs        9659 non-null   object
#  7   Type            9659 non-null   object
#  8   Price           9659 non-null   object
#  9   Content Rating  9659 non-null   object
#  10  Genres          9659 non-null   object
#  11  Last Updated    9659 non-null   object
#  12  Current Ver     9651 non-null   object
#  13  Android Ver     9657 non-null   object
# dtypes: float64(2), int64(2), object(10)
# memory usage: 1.0+ MB

# %%
df=df.iloc[:,1:]

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159  19.0      10,000+  Free     0       Everyone
# 1      967  14.0     500,000+  Free     0       Everyone
# 2    87510   8.7   5,000,000+  Free     0       Everyone
# 3   215644  25.0  50,000,000+  Free     0           Teen
# 4      967   2.8     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.describe()
# Out:
#             Rating       Reviews         Size
# count  8196.000000  9.659000e+03  8432.000000
# mean      4.173243  2.165926e+05    20.395327
# std       0.536625  1.831320e+06    21.827509
# min       1.000000  0.000000e+00     0.000000
# 25%       4.000000  2.500000e+01     4.600000
# 50%       4.300000  9.670000e+02    12.000000
# 75%       4.500000  2.940100e+04    28.000000
# max       5.000000  7.815831e+07   100.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9659 entries, 0 to 9658
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9659 non-null   object
#  1   Category        9659 non-null   object
#  2   Rating          8196 non-null   float64
#  3   Reviews         9659 non-null   int64
#  4   Size            8432 non-null   float64
#  5   Installs        9659 non-null   object
#  6   Type            9659 non-null   object
#  7   Price           9659 non-null   object
#  8   Content Rating  9659 non-null   object
#  9   Genres          9659 non-null   object
#  10  Last Updated    9659 non-null   object
#  11  Current Ver     9651 non-null   object
#  12  Android Ver     9657 non-null   object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 981.1+ KB

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1463
# Reviews              0
# Size              1227
# Installs             0
# Type                 0
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %%
df.shape
# Out:
# (9659, 13)

# %%
df.dropna(subset=['Rating'],axis=0,inplace=True)

# %%
df['Size'].astype('category').value_counts().index[0]
# Out:
# 14.0

# %%
df['Size'].fillna(df['Size'].astype('category').value_counts().index[0],inplace=True)

# %%
# df=df[df['Rating'].notnull()]

# %%
df['Current Ver'].value_counts()
# Out:
# Varies with device            1011
# 1                              467
# 1.1                            202
# 1.2                            132
# 2                              127
#                               ...
# 8.1.2                            1
# 1.5.18                           1
# 8.9                              1
# Natalia Studio Development       1
# 0.3.4                            1
# Name: Current Ver, Length: 2580, dtype: int64

# %%
df['Current Ver'].fillna(df['Current Ver'].mode()[0],inplace=True)

# %%
df['Android Ver'].fillna(df['Android Ver'].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size              float64
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %% [markdown]
# ## Price variable – remove   $ sign and convert to float

# %%
df['Price']=df['Price'].str.replace('$','')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15916\3004727282.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Price']=df['Price'].str.replace('$','')

# %%
df['Price'].unique()
# Out:
# array(['0', '4.99', '3.99', '6.99', '7.99', '5.99', '2.99', '3.49',
#        '1.99', '9.99', '7.49', '0.99', '9.00', '5.49', '10.00', '24.99',
#        '11.99', '79.99', '16.99', '14.99', '29.99', '12.99', '2.49',
#        '10.99', '1.50', '19.99', '15.99', '33.99', '39.99', '3.95',
#        '4.49', '1.70', '8.99', '1.49', '3.88', '399.99', '17.99',
#        '400.00', '3.02', '1.76', '4.84', '4.77', '1.61', '2.50', '1.59',
#        '6.49', '1.29', '299.99', '379.99', '37.99', '18.99', '389.99',
#        '8.49', '1.75', '14.00', '2.00', '3.08', '2.59', '19.40', '3.90',
#        '4.59', '15.46', '3.04', '13.99', '4.29', '3.28', '4.60', '1.00',
#        '2.95', '2.90', '1.97', '2.56', '1.20'], dtype=object)

# %%
df['Price']=df['Price'].astype('float')

# %% [markdown]
# ## Installs – remove ‘,’ and ‘+’ sign, convert to integer

# %%
df['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '100+', '500+', '10+',
#        '5+', '50+', '1+'], dtype=object)

# %%
df['Installs']=df['Installs'].str.replace('+','')
df['Installs']=df['Installs'].str.replace(',','')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15916\3707023661.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Installs']=df['Installs'].str.replace('+','')

# %%
df['Installs'].unique()
# Out:
# array(['10000', '500000', '5000000', '50000000', '100000', '50000',
#        '1000000', '10000000', '5000', '100000000', '1000000000', '1000',
#        '500000000', '100', '500', '10', '5', '50', '1'], dtype=object)

# %%
df['Installs']=df['Installs'].astype('int')

# %% [markdown]
# ## Convert all other identified columns to numeric

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8196 entries, 0 to 9658
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8196 non-null   object
#  1   Category        8196 non-null   object
#  2   Rating          8196 non-null   float64
#  3   Reviews         8196 non-null   int64
#  4   Size            8196 non-null   float64
#  5   Installs        8196 non-null   int32
#  6   Type            8196 non-null   object
#  7   Price           8196 non-null   float64
#  8   Content Rating  8196 non-null   object
#  9   Genres          8196 non-null   object
#  10  Last Updated    8196 non-null   object
#  11  Current Ver     8196 non-null   object
#  12  Android Ver     8196 non-null   object
# dtypes: float64(3), int32(1), int64(1), object(8)
# memory usage: 864.4+ KB

# %% [raw]
# From the given info, we have already converted the identifies columns into the numeric type so now, there are no such columns which we need to convert to numeric type

# %% [markdown]
# ##  Avg. rating should be between 1 and 5, as only these values are allowed on the play store.

# %%
df[df['Rating']>5].value_counts()
# Out:
# Series([], dtype: int64)

# %% [markdown]
# There are no such records which have rating greater than 5, so we don't need to drop anything from the given dataset

# %% [markdown]
# ## Reviews should not be more than installs as only those who installed can review the app.

# %%
df=df[df['Reviews']<df['Installs']]

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      159  19.0     10000  Free    0.0       Everyone
# 1      967  14.0    500000  Free    0.0       Everyone
# 2    87510   8.7   5000000  Free    0.0       Everyone
# 3   215644  25.0  50000000  Free    0.0           Teen
# 4      967   2.8    100000  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# ## After performing the operations, we found 7 such records which were greater than the installs so we droped those records So, now there are no such records that is Review which are greater than the installs

# %% [markdown]
# ## Identify and handle outliers –
# ### a. Price column
# ### i. Make suitable plot to identify outliers in price

# %%
df.boxplot('Price')
# Out:
# <Axes: >

# %% [raw]
# So, after ploting the boxplot for the Price column, we can see that there are some outliers present in the price column And from this we can assume that, there are outliers beyond value 50

# %% [markdown]
# ##  Do you expect apps on the play store to cost $200? Check out these cases

# %%
len(df[df['Price']>200])
# Out:
# 15

# %%
df=df[df['Price']<200]

# %%
df[df['Price']>200].value_counts()
# Out:
# Series([], dtype: int64)

# %%
df[df['Reviews']==78158306]
# Out:
#            App Category  Rating   Reviews  Size    Installs  Type  Price  \
# 2002  Facebook   SOCIAL     4.1  78158306  14.0  1000000000  Free    0.0
#
#      Content Rating  Genres    Last Updated         Current Ver  \
# 2002           Teen  Social  August 3, 2018  Varies with device
#
#              Android Ver
# 2002  Varies with device

# %%
df.sort_values(by='Reviews',ascending=False).head()['App']
# Out:
# 2002                                    Facebook
# 300                           WhatsApp Messenger
# 2003                                   Instagram
# 299     Messenger – Text and Video Chat for Free
# 1372                              Clash of Clans
# Name: App, dtype: object

# %%
## Facebook had maximum number of reviews so we can say that facebook is reviewed by the most of the people

# %% [markdown]
# ## Does the size of app affect the installation

# %%
a=df.groupby(['Size'])['Installs'].count().sort_values(ascending=False).reset_index()

# %%
a.sort_values(by='Size',ascending=False)
# Out:
#       Size  Installs
# 164  100.0        14
# 90    99.0        29
# 174   98.0        11
# 175   97.0        11
# 131   96.0        22
# ..     ...       ...
# 104    0.4        26
# 94     0.3        28
# 63     0.2        37
# 78     0.1        31
# 137    0.0        22
#
# [191 rows x 2 columns]

# %%
plt.scatter(x=df['Size'],y=df['Installs'])
plt.xlabel("Size")
plt.ylabel("Installs")
plt.show()

# %% [markdown]
# ### Size is affecting the number of installs

# %%
df.groupby(['Category'])['Installs'].count().sort_values(ascending=False).reset_index().head()
# Out:
#           Category  Installs
# 0           FAMILY      1604
# 1             GAME       908
# 2            TOOLS       718
# 3     PRODUCTIVITY       301
# 4  PERSONALIZATION       298

# %%
df.groupby(['Category'])['Installs'].count().sort_values(ascending=False).reset_index().head().plot(kind='bar')
plt.show()

# %% [raw]
#  If you have create a app then you must consider the above five categories

# %% [markdown]
# ## What is the distribution of ratings like? (use Seaborn) More skewed towards higher/lower values?

# %%
sns.distplot(df.Rating)
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15916\2919852989.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Rating)

# %% [raw]
# More number of app have 3 to 5 ratings

# %%
df[df['Type']=='Free']['App'].count()
# Out:
# 7586

# %%
df[df['Type']=='Paid']['App'].count()
# Out:
# 586

# %% [markdown]
# Most of the apps which are availble are free

# %% [markdown]
# ### Effect of size on rating
# #### Make a joinplot to understand the effect of size on rating

# %%
sns.jointplot(x='Size',y='Rating',data=df)
plt.show()

# %% [raw]
# Do you see any patterns?
# Yes, from the given plot, we can say that there is correlation between Size and Rating

# %% [raw]
# How do you explain the pattern?
# From the given plot, we can see that, on increase in the Rating, the size also increases and there is positive correlation between Size and Rating

# %% [markdown]
# ### Effect of price on rating
# ####  Make a jointplot (with regression line)

# %%
sns.jointplot(x='Price',y='Rating',data=df, kind='reg')
plt.show()

# %% [raw]
# What pattern do you see?
# From the given plot, we can say that, on increase in the Price, the Rating remains constant which is greater than 4

# %% [raw]
# How do you explain the pattern?
# So, here as on increase in price the rating remains constant which greater than 4 so we can say that, there is weak positive correlation between Rating and Price

# %%
greatervalue=df[df['Price']>0]
greatervalue
# Out:
#                                                 App            Category  \
# 233   TurboScan: scan documents and receipts in PDF            BUSINESS
# 234                  Tiny Scanner Pro: PDF Doc Scan            BUSINESS
# 372                              Puffin Browser Pro       COMMUNICATION
# 406                       Moco+ - Chat, Meet People              DATING
# 407                                      Calculator              DATING
# ...                                             ...                 ...
# 9505                            Fruit Ninja Classic                GAME
# 9513                                       FO Bixby     PERSONALIZATION
# 9579                                Fast Tract Diet  HEALTH_AND_FITNESS
# 9600                        Trine 2: Complete Story                GAME
# 9603                                   sugar, sugar              FAMILY
#
#       Rating  Reviews  Size  Installs  Type  Price Content Rating  \
# ...

# %%
sns.jointplot(x='Price',y='Rating',data=greatervalue, kind='reg')
plt.show()

# %% [raw]
# Does the pattern change?
# Yes, the pattern has changed as we have given the condition to the data as Price>0 so we can say that there is negative correlation between Price and Rating
#
#  What is your overall inference on the effect of price on the rating
# So, from this we can say that, on increase in the price, it doesn't have any effect on the higher rating and the rating is almost constant which is 4
#
# Look at all the numeric interactions together –
# Make a pairplort with the colulmns - 'Reviews', 'Size', 'Rating', 'Price'

# %%
sns.pairplot(df,vars=['Reviews','Size','Rating','Price'])
plt.show()

# %% [markdown]
# # Insights

# %% [markdown]
# #### If your app is of categories = {Family, Game, Tools, Productivity, Personalization} chances of it getting installed by more number of people is more
# #### As the size of App is small then the preerence of people downloading it is more
# #### If your app id Free of Cost then more people will install it
# #### If you want to create an app then Social Categoy is Suggested
