# %% [markdown]
# <a href="https://colab.research.google.com/github/yashsahu27420/PWAssignment/blob/main/Matplotlib_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing the necessary library
import numpy as np
import matplotlib.pyplot as plt

# %%
#Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.

# %%
#Answer 1
"""Matplotlib is a Python library used for creating cool visualizations and plots. It's handy for showing data in a visually appealing way. With Pyplot, you can make Line Plots, Scatter Plots, Bar Plots, Histograms, and Pie Charts. It's a must for data geeks!"""
# Out:
# "Matplotlib is a Python library used for creating cool visualizations and plots. It's handy for showing data in a visually appealing way. With Pyplot, you can make Line Plots, Scatter Plots, Bar Plots, Histograms, and Pie Charts. It's a must for data geeks!"

# %%
"""Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
plot a scatter plot.

import matplotlib.pyplot as plt
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('this is title')
plt.scatter(x,y)
plt.show() """

# %%
#Answer 2
#A scatter plot is a type of data visualization that shows the relationship between two variables.
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

plt.scatter(x, y)
plt.title("Scatter Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
""" Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
Use the following data:
import numpy as np
For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])"""

# %%
#Answer 3
#The subplot() function in Matplotlib is used to create multiple subplots within a single figure.
x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])

x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])

x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])

x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])

plt.subplot(2, 2, 1)
plt.plot(x1, y1)
plt.title("Line 1")

plt.subplot(2, 2, 2)
plt.plot(x2, y2)
plt.title("Line 2")

plt.subplot(2, 2, 3)
plt.plot(x3, y3)
plt.title("Line 3")

plt.subplot(2, 2, 4)
plt.plot(x4, y4)
plt.title("Line 4")

plt.tight_layout()
plt.show()

# %%
 """ Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])"""
# Out:
# ' Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.\nimport numpy as np\ncompany = np.array(["Apple", "Microsoft", "Google", "AMD"])\nprofit = np.array([3000, 8000, 1000, 10000])'

# %%
#Answer 4
#A bar plot, or bar chart, is a graph that uses rectangular bars to represent categorical data.

company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# Bar plot
plt.bar(company, profit)
plt.title("Bar Plot")
plt.xlabel("Company")
plt.ylabel("Profit (in billions)")

plt.show()

# Horizontal bar plot
plt.barh(company, profit)
plt.title("Horizontal Bar Plot")
plt.xlabel("Profit (in billions)")
plt.ylabel("Company")

plt.show()

# %%
#Answer 5
# Box plots, also known as box and whisker plots, are used to show the distribution of numeric data values
box1 = np.random.normal(101, 10, 205)
box2 = np.random.normal(93, 20, 205)

data = [box1, box2]

plt.boxplot(data, labels=["Box 1", "Box 2"])
plt.title("Box Plot")
plt.xlabel("Box")
plt.ylabel("Value")

plt.show()
